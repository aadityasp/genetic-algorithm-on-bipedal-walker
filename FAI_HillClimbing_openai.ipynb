# %%
import gym
import numpy as np
from numpy.random import randn
from numpy.random import rand
import itertools

# %% [markdown]
# ## Observations
# ## Type: Box(24)
#
# |Num|	  Observation |              Min	|     Max	|Mean|
# | --- | --- | --- |--- | --- |
# |0	|hull_angle	           |     0	  |  2*pi| 0.5|
# |1	|hull_angularVelocity	 |  -inf	|    +inf|	-|
# |2|	vel_x                    |   -1	    |+1	  |  -|
# |3|	vel_y	                 |   -1	    |+1	|-|
# |4|	hip_joint_1_angle	     |  -inf	    |+inf|	-|
# |5	|hip_joint_1_speed	     |   -inf	|+inf	|-|
# |6|	knee_joint_1_angle   	 |  -inf	    | +inf|	-|
# |7|	knee_joint_1_speed	     |  -inf	     |+inf|	-|
# |8	|leg_1_ground_contact_flag|	 0	     | 1	|-|
# |9	|hip_joint_2_angle	      | -inf  	|+inf	|-|
# |10	|hip_joint_2_speed	      |-inf   	|+inf	|-|
# |11	|knee_joint_2_angle	      | -inf  	|+inf	|-|
# |12	|knee_joint_2_speed	       |-inf	    |+inf|	-|
# |13	|leg_2_ground_contact_flag	|  0	    |  1|	    -|
# |14-23|	10 lidar readings	    |-inf	|+inf	|-|

# %% [markdown]
# ## Actions :
#
# |Num|	Name|	Min	|Max|
# | --- | --- | --- |--- |
# |0	|Hip_1 (Torque / Velocity)	|-1	|+1|
# |1|	Knee_1 (Torque / Velocity)	|-1	|+1|
# |2	|Hip_2 (Torque / Velocity)	|-1	|+1
# |3|	Knee_2 (Torque / Velocity)	|-1	|+1

# %%
env_name=  "BipedalWalker-v3"
env= gym.make(env_name)
# env.reset()
# # for _ in range(1000):
# #     env.render()
# #     env.step(env.action_space.sample()) # take a random action
# # #     print("Observation space:", env.observation_space)
# # #     print("Action space:", env.action_space)
# env.close()
# Out:
# /home/aadityasp/Aditya/Projects/FAI_prjt/fai/lib/python3.8/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
def Objective_fun(action):
    observation, reward, done, info = env.step(action)
    return reward,done
# neighbors_rewards_andstatus=[]

hip_1_range= [x / 100.0 for x in range(-100, 101, 1)]
#     print(hip_1_range)
hip_2_range= [x / 100.0 for x in range(-100, 101, 1)]
knee_1_range= [x / 100.0 for x in range(-100, 101, 1)]
knee_2_range= [x / 100.0 for x in range(-100, 101, 1)]

action= env.action_space.sample()
action = action.tolist()
print(action)
a,b,c,d= action
if hip_1_range.index(round(a, 2)) >0:
#     print(round(a, 2))
    hip1_neighbors= [hip_1_range[hip_1_range.index(round(a, 2))-1],hip_1_range[hip_1_range.index(round(a, 2))+1] ]
elif hip_1_range.index(a)==0:
     hip1_neighbors= [hip_1_range[hip_1_range.index(a)+1]]
        
        
if hip_2_range.index(round(c, 2)) >0:
    hip2_neighbors= [hip_2_range[hip_2_range.index(round(c, 2))-1],hip_2_range[hip_2_range.index(round(c, 2))+1] ]
elif hip_2_range.index(round(c, 2))==0:
     hip2_neighbors= [hip_2_range[hip_2_range.index(round(c, 2))+1]]        
        
if knee_1_range.index(round(b, 2)) >0:
    knee1_neighbors= [knee_1_range[knee_1_range.index(round(b, 2))-1],knee_1_range[knee_1_range.index(round(b, 2))+1] ]
elif knee_1_range.index(round(b, 2))==0:
     knee1_neighbors= [knee_1_range[knee_1_range.index(round(b, 2))+1]]        
        
if knee_2_range.index(round(d, 2)) >0:
    knee2_neighbors= [knee_2_range[knee_2_range.index(round(d, 2))-1],knee_2_range[knee_2_range.index(round(d, 2))+1] ]
elif knee_2_range.index(round(d, 2))==0:
     knee2_neighbors= [knee_2_range[knee_2_range.index(round(d, 2))+1]]     

# new_action = np.array([0.0, 0.0, 0.0, 0.0])
# Out:
# [-0.4853542745113373, 0.9147047400474548, -0.461005836725235, 0.9727874994277954]

# %%
for i_episode in range(20):
    observation = env.reset()
    s = observation
    neighbors_rewards_andstatus=[]
    for t in range(100):
        env.render()
#         print(observation[0])
#         print("ACTION SPACE=", env.action_space.sample())
        neighboring_actions= list(itertools.product(hip1_neighbors,hip2_neighbors,knee1_neighbors,knee2_neighbors))
#         print("Neighboring actions=",neighboring_actions)
        for neighbor in neighboring_actions:
            neighbors_rewards_andstatus += [Objective_fun(neighbor)]
#             print(0.9*(0-s[0]) - 1.5*s[1])
#         next_action= neighboring_actions.index(np.amax(neighbors_rewards))
            print("Rewards=",neighbors_rewards_andstatus[0])
#         action = env.action_space.sample()
#         observation, reward, done, info = env.step(action)
            if neighbors_rewards_andstatus[-1]:
                print("Episode finished after {} timesteps".format(t+1))
                break
env.close()
# Out:
# Rewards= (-0.06980442404010881, False)
# Episode finished after 1 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 2 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 3 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 4 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 5 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 6 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 7 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 8 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 9 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 10 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 11 timesteps
# Rewards= (-0.06980442404010881, False)
# Episode finished after 12 timesteps
# Rewards= (-0.06980442404010881, False)
# ...

# %%
class Agent():
    def __init__(self,env):
        self.hip_1_range= [x / 100.0 for x in range(-100, 101, 1)]
#     print(hip_1_range)
        self.hip_2_range= [x / 100.0 for x in range(-100, 101, 1)]
        self.knee_1_range= [x / 100.0 for x in range(-100, 101, 1)]
        self.knee_2_range= [x / 100.0 for x in range(-100, 101, 1)]

        pass
    def next_action(self,state):
        
        return action
